# %% [markdown]
# ## In this notebook iwe will emulate Potential Temperature variable of the WRF data . We have saprately fetched the data from 2019-05-01 to 2019-05-31 in pickel files.
#
# ## The location we will focus at UMBC in Maryland.
#
# ## The data will be divided in 70% training and 30% testing, ie Model will be roughly trained on first 20 days and evalute on next 10 days.

# %%
from netCDF4 import Dataset
from netCDF4 import num2date, date2num
import netCDF4
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
import autokeras as ak
from math import sqrt
from tensorflow.keras.regularizers import l2, l1
import time
from mpl_toolkits.basemap import Basemap
import argparse
import matplotlib as mpl

# %% [markdown]
# ### Retreiving data from Pickel file

# %%
datafile = open('PickleDataFiles/wrfout_d01_2019_05_01_to_2019_05_31_TPWHNO', 'rb')      
data = pickle.load(datafile)

# %% [markdown]
# ### For this notebook we will focus on 'latitude', 'longitude', 'Temperature' variables

# %%
data.keys()
# Out:
# dict_keys(['times', 'latitude', 'longitude', 'temperature', 'xWind', 'yWind', 'zWind', 'pressure', 'no2', 'no', 'o3', 'hno3', 'h2o2'])

# %% [markdown]
# ### Among all the latitude longitude points, these points lies in UMBC

# %%
#'UMBC'
print(data['latitude'][17][20])
print(data['longitude'][17][20])
# Out:
# 39.589718
# -76.512085

# %%
print('times :' + str(len(data['times'])))
print('Lat :' + str(data['latitude'].shape))
print('Lon :' + str(data['longitude'].shape))
print('Pressure :' + str(data['pressure'].shape))
print('Temperature :' + str(data['temperature'].shape))
# Out:
# times :744
# Lat :(29, 29)
# Lon :(29, 29)
# Pressure :(744, 29, 29, 29)
# Temperature :(744, 29, 29, 29)

# %% [markdown]
# - We can see above that total we have 29*29 Latitude and Longitude Points
# - We have 744 data point for a month ie, we have data for each hour (31*24 = 744)
# - For Temperature and Pressure we have 29 level of the data and at each level we have 29*29 gird points at each lat-lon point

# %% [markdown]
# ### Next we will retrieve all the 29 level data point of all the variables at the UMBC. Storing them to respective list

# %%
lat_loc=17
lon_loc=20
temperature =[]
pressure = []
xWind = []
yWind = []
zWind = []
no2 = []
no = []
o3 = []
hno3 = []
h2o2 = []
for i in range(len(data['temperature'])):
    temperature.append(data['temperature'][i][lat_loc][lon_loc])
    pressure.append(data['pressure'][i][lat_loc][lon_loc])
    xWind.append(data['xWind'][i][lat_loc][lon_loc])
    yWind.append(data['yWind'][i][lat_loc][lon_loc])
    zWind.append(data['zWind'][i][lat_loc][lon_loc])
    no2.append(data['no2'][i][lat_loc][lon_loc])
    no.append(data['no'][i][lat_loc][lon_loc])
    o3.append(data['o3'][i][lat_loc][lon_loc])
    hno3.append(data['hno3'][i][lat_loc][lon_loc])
    h2o2.append(data['h2o2'][i][lat_loc][lon_loc])

# %% [markdown]
# ### As this is time series data so first thing came to mind is to use RNN. A Recurrent Neural Network (RNN) is a type of neural network well-suited to time series data. RNNs process a time series step-by-step, maintaining an internal state from time-step to time-step.
# ### This is Univariate RNN model, so our input and output variable are both Temperature.
# ### For RNN we need 3D format, and split the data into 3 steps such that first three steps are input and fourth step is the output

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            print("break")
            print(i)
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
X,y=split_sequence(temperature, 3)
# Out:
# break
# 741

# %%
X.shape
# Out:
# (741, 3, 29)

# %%
y.shape
# Out:
# (741, 29)

# %% [markdown]
# ### Splitting the data with test size of 33 %

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (496, 3, 29)
# (245, 3, 29)

# %% [markdown]
# ### In order to make the model learning easy, lets standardise the input data

# %%
scaler = MinMaxScaler(feature_range=(0,1))
X_train = scaler.fit_transform(X_train.reshape(X_train.shape[0], -1)).reshape(X_train.shape)
X_test = scaler.transform(X_test.reshape(X_test.shape[0], -1)).reshape(X_test.shape)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (496, 3, 29)
# (245, 3, 29)

# %% [markdown]
# ### Creating our own loss function as root mean square

# %%
def my_objective(y_pred,  y_true):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred-y_true)))

# %% [markdown]
# How autokeras library works is that, it gives us best neural network architecture on the given input data.
#
# We can use different block such as DenseBlock, ConvBlock, RNNBlock based on our problem.
#
# The input_node is to accept the input datato the model.
# Then we added RNN block with few parameter inputs. This requires little bit of hyperparameter tunning on below variables.
#     - return_sequences: Boolean. Whether to return the last output. in the output sequence, or the full sequence. Default: False. This was set to True to get the full sequence.
#     - bidirectional: It involves duplicating the first recurrent layer in the network so that there are now two layers side-by-side, then providing the input sequence as-is as input to the first layer and providing a reversed copy of the input sequence to the second.
#     - layer_type: it can be lstm/GRU. if left empty the RNNBlock will identify the best one.
#
# For the ouptut we define RegressionHead with our own loss.
#
# Lastly setting the autokeras AutoModel, specifying input_node, output_node and max_trials. In each epoch the autokers will try different architecture upto max_trial
#
# Then standard Model.fit with input and output data with number of epochs

# %%
input_node = ak.Input()
output_node2 = ak.RNNBlock(return_sequences=True,bidirectional=True,layer_type='lstm')(input_node) 

output_node = ak.RegressionHead(loss=my_objective)(output_node2)

auto_model = ak.AutoModel(inputs=input_node,outputs=output_node,overwrite=True,max_trials=50)

# %%
start_time = time.time()
auto_model.fit(X_train, y_train, epochs=100)
# Out:
# Trial 11 Complete [00h 00m 14s]
# val_loss: 1.0625948905944824
#
# Best val_loss So Far: 0.5758088231086731
# Total elapsed time: 00h 04m 09s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 17/17 [==============================] - 1s 71ms/step - loss: 13.0468 - mean_squared_error: 170.3276 - val_loss: 12.5785 - val_mean_squared_error: 158.3277
# Epoch 2/100
# 17/17 [==============================] - 0s 10ms/step - loss: 11.7030 - mean_squared_error: 137.5237 - val_loss: 9.9807 - val_mean_squared_error: 99.6894
# Epoch 3/100
# 17/17 [==============================] - 0s 9ms/step - loss: 8.3234 - mean_squared_error: 70.3523 - val_loss: 6.4481 - val_mean_squared_error: 41.6073
# Epoch 4/100
# 17/17 [==============================] - 0s 9ms/step - loss: 5.5074 - mean_squared_error: 30.5460 - val_loss: 5.0331 - val_mean_squared_error: 25.3634
# Epoch 5/100
# 17/17 [==============================] - 0s 10ms/step - loss: 4.6745 - mean_squared_error: 21.9134 - val_loss: 4.7201 - val_mean_squared_error: 22.3031
# Epoch 6/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.5413 - mean_squared_error: 20.6779 - val_loss: 4.6759 - val_mean_squared_error: 21.8843
# Epoch 7/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.5275 - mean_squared_error: 20.5550 - val_loss: 4.6744 - val_mean_squared_error: 21.8723
# Epoch 8/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.5190 - mean_squared_error: 20.4792 - val_loss: 4.6676 - val_mean_squared_error: 21.8077
# Epoch 9/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.5099 - mean_squared_error: 20.3955 - val_loss: 4.6546 - val_mean_squared_error: 21.6857
# Epoch 10/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.4961 - mean_squared_error: 20.2703 - val_loss: 4.6346 - val_mean_squared_error: 21.4989
# Epoch 11/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.4711 - mean_squared_error: 20.0442 - val_loss: 4.5953 - val_mean_squared_error: 21.1341
# Epoch 12/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.4231 - mean_squared_error: 19.6135 - val_loss: 4.5175 - val_mean_squared_error: 20.4220
# Epoch 13/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.3306 - mean_squared_error: 18.7994 - val_loss: 4.3917 - val_mean_squared_error: 19.2995
# Epoch 14/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.2107 - mean_squared_error: 17.7739 - val_loss: 4.2881 - val_mean_squared_error: 18.4015
# Epoch 15/100
# 17/17 [==============================] - 0s 9ms/step - loss: 4.1142 - mean_squared_error: 16.9702 - val_loss: 4.1781 - val_mean_squared_error: 17.4693
# Epoch 16/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.9963 - mean_squared_error: 16.0125 - val_loss: 4.0330 - val_mean_squared_error: 16.2768
# Epoch 17/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.8346 - mean_squared_error: 14.7432 - val_loss: 3.8368 - val_mean_squared_error: 14.7314
# Epoch 18/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.6213 - mean_squared_error: 13.1515 - val_loss: 3.5906 - val_mean_squared_error: 12.9016
# Epoch 19/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.3739 - mean_squared_error: 11.4190 - val_loss: 3.3582 - val_mean_squared_error: 11.2863
# Epoch 20/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.1620 - mean_squared_error: 10.0326 - val_loss: 3.1776 - val_mean_squared_error: 10.1055
# Epoch 21/100
# 17/17 [==============================] - 0s 9ms/step - loss: 3.0084 - mean_squared_error: 9.0826 - val_loss: 3.0465 - val_mean_squared_error: 9.2906
# Epoch 22/100
# 17/17 [==============================] - 0s 9ms/step - loss: 2.8848 - mean_squared_error: 8.3517 - val_loss: 2.9222 - val_mean_squared_error: 8.5489
# Epoch 23/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.7466 - mean_squared_error: 7.5700 - val_loss: 2.7557 - val_mean_squared_error: 7.6045
# Epoch 24/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.5682 - mean_squared_error: 6.6180 - val_loss: 2.5471 - val_mean_squared_error: 6.5005
# Epoch 25/100
# 17/17 [==============================] - 0s 9ms/step - loss: 2.3747 - mean_squared_error: 5.6579 - val_loss: 2.3575 - val_mean_squared_error: 5.5746
# Epoch 26/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.2060 - mean_squared_error: 4.8835 - val_loss: 2.2087 - val_mean_squared_error: 4.8984
# Epoch 27/100
# 17/17 [==============================] - 0s 10ms/step - loss: 2.0707 - mean_squared_error: 4.3045 - val_loss: 2.0829 - val_mean_squared_error: 4.3604
# Epoch 28/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.9539 - mean_squared_error: 3.8333 - val_loss: 1.9678 - val_mean_squared_error: 3.8952
# Epoch 29/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.8420 - mean_squared_error: 3.4062 - val_loss: 1.8570 - val_mean_squared_error: 3.4720
# Epoch 30/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.7332 - mean_squared_error: 3.0141 - val_loss: 1.7493 - val_mean_squared_error: 3.0838
# Epoch 31/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.6402 - mean_squared_error: 2.6997 - val_loss: 1.6475 - val_mean_squared_error: 2.7365
# Epoch 32/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.5566 - mean_squared_error: 2.4317 - val_loss: 1.5750 - val_mean_squared_error: 2.5014
# Epoch 33/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.4963 - mean_squared_error: 2.2469 - val_loss: 1.5165 - val_mean_squared_error: 2.3194
# Epoch 34/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.4450 - mean_squared_error: 2.0952 - val_loss: 1.4592 - val_mean_squared_error: 2.1478
# Epoch 35/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.4015 - mean_squared_error: 1.9706 - val_loss: 1.4145 - val_mean_squared_error: 2.0178
# Epoch 36/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.3595 - mean_squared_error: 1.8539 - val_loss: 1.3710 - val_mean_squared_error: 1.8955
# Epoch 37/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.3179 - mean_squared_error: 1.7421 - val_loss: 1.3225 - val_mean_squared_error: 1.7630
# Epoch 38/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.2738 - mean_squared_error: 1.6269 - val_loss: 1.2757 - val_mean_squared_error: 1.6394
# Epoch 39/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.2309 - mean_squared_error: 1.5190 - val_loss: 1.2312 - val_mean_squared_error: 1.5264
# Epoch 40/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.1869 - mean_squared_error: 1.4121 - val_loss: 1.1919 - val_mean_squared_error: 1.4302
# Epoch 41/100
# 17/17 [==============================] - 0s 10ms/step - loss: 1.1460 - mean_squared_error: 1.3164 - val_loss: 1.1645 - val_mean_squared_error: 1.3649
# Epoch 42/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.1070 - mean_squared_error: 1.2280 - val_loss: 1.1235 - val_mean_squared_error: 1.2699
# Epoch 43/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.0696 - mean_squared_error: 1.1465 - val_loss: 1.0830 - val_mean_squared_error: 1.1796
# Epoch 44/100
# 17/17 [==============================] - 0s 9ms/step - loss: 1.0300 - mean_squared_error: 1.0632 - val_loss: 1.0383 - val_mean_squared_error: 1.0835
# Epoch 45/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.9959 - mean_squared_error: 0.9939 - val_loss: 1.0068 - val_mean_squared_error: 1.0183
# Epoch 46/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9674 - mean_squared_error: 0.9378 - val_loss: 0.9825 - val_mean_squared_error: 0.9693
# Epoch 47/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.9424 - mean_squared_error: 0.8899 - val_loss: 0.9577 - val_mean_squared_error: 0.9207
# Epoch 48/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.9194 - mean_squared_error: 0.8470 - val_loss: 0.9333 - val_mean_squared_error: 0.8740
# Epoch 49/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8993 - mean_squared_error: 0.8104 - val_loss: 0.9096 - val_mean_squared_error: 0.8300
# Epoch 50/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8813 - mean_squared_error: 0.7783 - val_loss: 0.8880 - val_mean_squared_error: 0.7908
# Epoch 51/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8651 - mean_squared_error: 0.7502 - val_loss: 0.8655 - val_mean_squared_error: 0.7511
# Epoch 52/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8494 - mean_squared_error: 0.7233 - val_loss: 0.8451 - val_mean_squared_error: 0.7160
# Epoch 53/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.8336 - mean_squared_error: 0.6966 - val_loss: 0.8284 - val_mean_squared_error: 0.6878
# Epoch 54/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8195 - mean_squared_error: 0.6732 - val_loss: 0.8132 - val_mean_squared_error: 0.6628
# Epoch 55/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.8070 - mean_squared_error: 0.6530 - val_loss: 0.7988 - val_mean_squared_error: 0.6396
# Epoch 56/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7949 - mean_squared_error: 0.6335 - val_loss: 0.7859 - val_mean_squared_error: 0.6190
# Epoch 57/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7833 - mean_squared_error: 0.6152 - val_loss: 0.7735 - val_mean_squared_error: 0.5996
# Epoch 58/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7724 - mean_squared_error: 0.5982 - val_loss: 0.7612 - val_mean_squared_error: 0.5807
# Epoch 59/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7615 - mean_squared_error: 0.5815 - val_loss: 0.7496 - val_mean_squared_error: 0.5631
# Epoch 60/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7508 - mean_squared_error: 0.5654 - val_loss: 0.7382 - val_mean_squared_error: 0.5462
# Epoch 61/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.7406 - mean_squared_error: 0.5501 - val_loss: 0.7271 - val_mean_squared_error: 0.5299
# Epoch 62/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7304 - mean_squared_error: 0.5350 - val_loss: 0.7167 - val_mean_squared_error: 0.5147
# Epoch 63/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7205 - mean_squared_error: 0.5205 - val_loss: 0.7069 - val_mean_squared_error: 0.5008
# Epoch 64/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7107 - mean_squared_error: 0.5066 - val_loss: 0.6970 - val_mean_squared_error: 0.4869
# Epoch 65/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.7007 - mean_squared_error: 0.4923 - val_loss: 0.6866 - val_mean_squared_error: 0.4726
# Epoch 66/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6901 - mean_squared_error: 0.4775 - val_loss: 0.6762 - val_mean_squared_error: 0.4584
# Epoch 67/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6796 - mean_squared_error: 0.4632 - val_loss: 0.6661 - val_mean_squared_error: 0.4448
# Epoch 68/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6696 - mean_squared_error: 0.4496 - val_loss: 0.6564 - val_mean_squared_error: 0.4320
# Epoch 69/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6601 - mean_squared_error: 0.4369 - val_loss: 0.6475 - val_mean_squared_error: 0.4205
# Epoch 70/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6511 - mean_squared_error: 0.4251 - val_loss: 0.6388 - val_mean_squared_error: 0.4094
# Epoch 71/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6429 - mean_squared_error: 0.4145 - val_loss: 0.6311 - val_mean_squared_error: 0.3996
# Epoch 72/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.6351 - mean_squared_error: 0.4045 - val_loss: 0.6239 - val_mean_squared_error: 0.3906
# Epoch 73/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6273 - mean_squared_error: 0.3946 - val_loss: 0.6170 - val_mean_squared_error: 0.3822
# Epoch 74/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6198 - mean_squared_error: 0.3853 - val_loss: 0.6105 - val_mean_squared_error: 0.3743
# Epoch 75/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6127 - mean_squared_error: 0.3766 - val_loss: 0.6042 - val_mean_squared_error: 0.3667
# Epoch 76/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.6061 - mean_squared_error: 0.3685 - val_loss: 0.5981 - val_mean_squared_error: 0.3594
# Epoch 77/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5999 - mean_squared_error: 0.3610 - val_loss: 0.5920 - val_mean_squared_error: 0.3523
# Epoch 78/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5940 - mean_squared_error: 0.3540 - val_loss: 0.5860 - val_mean_squared_error: 0.3453
# Epoch 79/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5885 - mean_squared_error: 0.3474 - val_loss: 0.5797 - val_mean_squared_error: 0.3381
# Epoch 80/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5832 - mean_squared_error: 0.3412 - val_loss: 0.5732 - val_mean_squared_error: 0.3306
# Epoch 81/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5780 - mean_squared_error: 0.3352 - val_loss: 0.5665 - val_mean_squared_error: 0.3231
# Epoch 82/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5728 - mean_squared_error: 0.3292 - val_loss: 0.5599 - val_mean_squared_error: 0.3156
# Epoch 83/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5677 - mean_squared_error: 0.3233 - val_loss: 0.5535 - val_mean_squared_error: 0.3086
# Epoch 84/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5625 - mean_squared_error: 0.3174 - val_loss: 0.5474 - val_mean_squared_error: 0.3020
# Epoch 85/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5573 - mean_squared_error: 0.3116 - val_loss: 0.5418 - val_mean_squared_error: 0.2959
# Epoch 86/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5521 - mean_squared_error: 0.3059 - val_loss: 0.5364 - val_mean_squared_error: 0.2902
# Epoch 87/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5472 - mean_squared_error: 0.3005 - val_loss: 0.5313 - val_mean_squared_error: 0.2849
# Epoch 88/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5425 - mean_squared_error: 0.2954 - val_loss: 0.5264 - val_mean_squared_error: 0.2798
# Epoch 89/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5380 - mean_squared_error: 0.2906 - val_loss: 0.5217 - val_mean_squared_error: 0.2750
# Epoch 90/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5338 - mean_squared_error: 0.2861 - val_loss: 0.5171 - val_mean_squared_error: 0.2703
# Epoch 91/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5297 - mean_squared_error: 0.2817 - val_loss: 0.5127 - val_mean_squared_error: 0.2658
# Epoch 92/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5257 - mean_squared_error: 0.2775 - val_loss: 0.5084 - val_mean_squared_error: 0.2616
# Epoch 93/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5218 - mean_squared_error: 0.2735 - val_loss: 0.5043 - val_mean_squared_error: 0.2576
# Epoch 94/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.5181 - mean_squared_error: 0.2696 - val_loss: 0.5004 - val_mean_squared_error: 0.2537
# Epoch 95/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5145 - mean_squared_error: 0.2659 - val_loss: 0.4967 - val_mean_squared_error: 0.2501
# Epoch 96/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5109 - mean_squared_error: 0.2623 - val_loss: 0.4931 - val_mean_squared_error: 0.2467
# Epoch 97/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5077 - mean_squared_error: 0.2590 - val_loss: 0.4896 - val_mean_squared_error: 0.2433
# Epoch 98/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5043 - mean_squared_error: 0.2556 - val_loss: 0.4864 - val_mean_squared_error: 0.2403
# Epoch 99/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.5014 - mean_squared_error: 0.2527 - val_loss: 0.4831 - val_mean_squared_error: 0.2371
# Epoch 100/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.4980 - mean_squared_error: 0.2493 - val_loss: 0.4807 - val_mean_squared_error: 0.2348

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 273.4953634738922 seconds ---

# %% [markdown]
# ### Now we can make predictions on the model we just trained.

# %%
start_time_prediction = time.time()
predicted_temp=auto_model.predict(X_test)
print("--- %s seconds ---" % (time.time() - start_time_prediction))
# Out:
# --- 2.5334525108337402 seconds ---

# %% [markdown]
# ### Export model to save the config

# %%
auto_model_t=auto_model.export_model()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
f = open("images_data/Temperature_Model_config_UMBC.txt", "w")
f.write(str(auto_model_t.get_config()))
f.close()

# %% [markdown]
# ### Save the trained model to make further predictions

# %%
try:
    auto_model_t.save("Model_save/model_autokeras_temperature_UMBC", save_format="tf")
except Exception:
    auto_model_t.save("Model_save/model_autokeras_temperature_UMBC.h5")
# Out:
# WARNING:tensorflow:From /home/rgite1/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/rgite1/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: Model_save/model_autokeras_temperature_UMBC/assets

# %%
auto_model_t.get_config()
# Out:
# {'name': 'functional_1',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 3, 29),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'input_1'},
#    'name': 'input_1',
#    'inbound_nodes': []},
#   {'class_name': 'Bidirectional',
#    'config': {'name': 'bidirectional',
#     'trainable': True,
#     'dtype': 'float32',
#     'layer': {'class_name': 'LSTM',
#      'config': {'name': 'lstm',
#       'trainable': True,
#       'dtype': 'float32',
#       'return_sequences': True,
#       'return_state': False,
#       'go_backwards': False,
#       'stateful': False,
#       'unroll': False,
#       'time_major': False,
#       'units': 29,
#       'activation': 'tanh',
#       'recurrent_activation': 'sigmoid',
#       'use_bias': True,
#       'kernel_initializer': {'class_name': 'GlorotUniform',
#        'config': {'seed': None}},
#       'recurrent_initializer': {'class_name': 'Orthogonal',
#        'config': {'gain': 1.0, 'seed': None}},
#       'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#       'unit_forget_bias': True,
#       'kernel_regularizer': None,
#       'recurrent_regularizer': None,
#       'bias_regularizer': None,
#       'activity_regularizer': None,
#       'kernel_constraint': None,
#       'recurrent_constraint': None,
#       'bias_constraint': None,
#       'dropout': 0.0,
#       'recurrent_dropout': 0.0,
#       'implementation': 2}},
#     'merge_mode': 'concat'},
#    'name': 'bidirectional',
#    'inbound_nodes': [[['input_1', 0, 0, {}]]]},
#   {'class_name': 'Bidirectional',
#    'config': {'name': 'bidirectional_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'layer': {'class_name': 'LSTM',
#      'config': {'name': 'lstm_1',
#       'trainable': True,
#       'dtype': 'float32',
#       'return_sequences': True,
#       'return_state': False,
#       'go_backwards': False,
#       'stateful': False,
#       'unroll': False,
#       'time_major': False,
#       'units': 29,
#       'activation': 'tanh',
#       'recurrent_activation': 'sigmoid',
#       'use_bias': True,
#       'kernel_initializer': {'class_name': 'GlorotUniform',
#        'config': {'seed': None}},
#       'recurrent_initializer': {'class_name': 'Orthogonal',
#        'config': {'gain': 1.0, 'seed': None}},
#       'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#       'unit_forget_bias': True,
#       'kernel_regularizer': None,
#       'recurrent_regularizer': None,
#       'bias_regularizer': None,
#       'activity_regularizer': None,
#       'kernel_constraint': None,
#       'recurrent_constraint': None,
#       'bias_constraint': None,
#       'dropout': 0.0,
#       'recurrent_dropout': 0.0,
#       'implementation': 2}},
#     'merge_mode': 'concat'},
#    'name': 'bidirectional_1',
#    'inbound_nodes': [[['bidirectional', 0, 0, {}]]]},
#   {'class_name': 'Flatten',
#    'config': {'name': 'flatten',
#     'trainable': True,
#     'dtype': 'float32',
#     'data_format': 'channels_last'},
#    'name': 'flatten',
#    'inbound_nodes': [[['bidirectional_1', 0, 0, {}]]]},
#   {'class_name': 'Dense',
#    'config': {'name': 'regression_head_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 29,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None},
#    'name': 'regression_head_1',
#    'inbound_nodes': [[['flatten', 0, 0, {}]]]}],
#  'input_layers': [['input_1', 0, 0]],
#  'output_layers': [['regression_head_1', 0, 0]]}

# %%
predicted_temp
# Out:
# array([[14.33883  , 14.807473 , 14.623261 , ..., 18.71816  , 19.680351 ,
#         20.062788 ],
#        [19.582819 , 20.087566 , 20.373684 , ...,  6.1222825,  8.983146 ,
#         11.630021 ],
#        [ 3.3779075,  2.5521183,  3.9426808, ..., 18.668306 , 20.835896 ,
#         20.94301  ],
#        ...,
#        [ 2.101042 ,  1.0261078,  2.8790443, ..., 18.164217 , 20.613417 ,
#         20.965784 ],
#        [20.936052 , 20.920996 , 20.110607 , ..., 20.964813 , 20.952826 ,
#         20.765469 ],
#        [12.828563 , 13.880074 , 14.794094 , ..., 17.702381 , 17.825802 ,
#         17.553787 ]], dtype=float32)

# %% [markdown]
# ### R-squared is a relative measure of fit, R-squared is around 98% reveals that 98% of the data fits the regression model.
# ### RMSE is an absolute measure of fit. RMSE is measure of the average deviation of the estimates from the observed values or is the square root of the variance of the residuals.

# %%
r2 = r2_score(predicted_temp,y_test)
rmse = sqrt(mean_squared_error(predicted_temp,y_test))

# %%
print(r2)
print(rmse)
# Out:
# 0.9814436868680273
# 0.5837368903229837

# %% [markdown]
# ### Lets Visualize the Test vs Predicted data

# %%
plt.figure(figsize=(10,8))
plt.title('Test vs Predicted,Temperature at UMBC')
plt.xlabel('Time')
plt.ylabel('Potential Temperature (K)')
plt.plot(y_test, 'r',label='Test')
plt.plot(predicted_temp, 'b',label='Predicted')
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.savefig('images_data/Temperature at UMBC.png')
#plt.legend()
plt.show()

# %% [markdown]
# ### The plot looks convencing as almost all test data points are covered by predicted data. To get a closer look lets plot the single time and location

# %% [markdown]
# ### The plot looks convencing as almost all test data points are covered by predicted data. To get a closer look lets plot the single time and location

# %%
plt.figure(figsize=(10,8))
plt.title('Test vs Predicted, Temperature for Single Time at UMBC')
plt.xlabel('Column Bottom to Top')
plt.ylabel('Potential Temperature (k)')
plt.plot(y_test[0], 'r',label= 'Test')
plt.plot(predicted_temp[0], 'b', label= 'Predicted')
plt.legend()
plt.savefig('images_data/Temperature for Single Time at UMBC_0.png')
plt.show()
#plt.savefig('Data/autoKeras_500_trials_1000epochs.png')
